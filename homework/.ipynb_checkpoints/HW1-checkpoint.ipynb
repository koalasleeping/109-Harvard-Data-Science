# %% [markdown]
# # Homework 1. Exploratory Data Analysis
#
# Due: Thursday, September 18, 2014 11:59 PM
#
# <a href=https://raw.githubusercontent.com/cs109/2014/master/homework/HW1.ipynb download=HW1.ipynb> Download this assignment</a>
#
# ---

# %% [markdown]
# ## Introduction
#
# In this homework we ask you three questions that we expect you to answer using data. For each question we ask you to complete a series of tasks that should help guide you through the data analysis. Complete these tasks and then write a short (100 words or less) answer to the question.
#
# **Note**: We will briefly discuss this homework assignment on Thursday in class.
#
# #### Data
# For this assignment we will use two databases:
#
# 1. The [Sean Lahman's Baseball Database](http://seanlahman.com/baseball-archive/statistics) which contains the "complete batting and pitching statistics from 1871 to 2013, plus fielding statistics, standings, team stats, managerial records, post-season data, and more. For more details on the latest release, please [read the documentation](http://seanlahman.com/files/database/readme2012.txt)."
#
# 2. [Gapminder](http://www.gapminder.org) is a great resource that contains over [500 data sets](http://www.gapminder.org/data/) related to world indicators such as income, GDP and life expectancy.
#
#
# #### Purpose
#
# In this assignment, you will learn how to:
#
# a. Load in CSV files from the web.
#
# b. Create functions in python.
#
# C. Create plots and summary statistics for exploratory data analysis such as histograms, boxplots and scatter plots.
#
#
# #### Useful libraries for this assignment
#
# * [numpy](http://docs.scipy.org/doc/numpy-dev/user/index.html), for arrays
# * [pandas](http://pandas.pydata.org/), for data frames
# * [matplotlib](http://matplotlib.org/), for plotting
#
# ---

# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Problem 1
#
# In Lecture 1, we showed a plot that provided evidence that the 2002 and 2003 Oakland A's, a team that used data science, had a competitive advantage. Since, others teams have started using data science as well. Use exploratory data analysis to determine if the competitive advantage has since disappeared.

# %% [markdown]
# #### Problem 1(a)
# Load in [these CSV files](http://seanlahman.com/files/database/lahman-csv_2014-02-14.zip) from the [Sean Lahman's Baseball Database](http://seanlahman.com/baseball-archive/statistics). For this assignment, we will use the 'Salaries.csv' and 'Teams.csv' tables. Read these tables into a pandas `DataFrame` and show the head of each table.
#
# **Hint** Use the [requests](http://docs.python-requests.org/en/latest/), [StringIO](http://docs.python.org/2/library/stringio.html) and [zipfile](https://docs.python.org/2/library/zipfile.html) modules to get from the web.

# %%
import zipfile

path = '/Users/xuhong/Documents/Duke/Term 1 Courses/MOOC/CS109 Harvard/2014/homework/'
zp = zipfile.ZipFile(path + 'lahman-csv_2014-02-14.zip')
Sal = zp.open('Salaries.csv')
Teams = zp.open('Teams.csv')

dfS = pd.read_csv(Sal)
dfT = pd.read_csv(Teams)

dfS.head()
dfT.head()
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L ...  DP    FP  \
# 0    1871  NaN    PH1      PNA   NaN     1  28    NaN  21   7 ... NaN  0.84
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9 ... NaN  0.82
# 2    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10 ... NaN  0.83
# 3    1871  NaN    WS3      OLY   NaN     4  32    NaN  15  15 ... NaN  0.85
# 4    1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17 ... NaN  0.83
#
#                       name                      park  attendance  BPF  PPF  \
# 0   Philadelphia Athletics  Jefferson Street Grounds         NaN  102   98
# 1  Chicago White Stockings   Union Base-Ball Grounds         NaN  104  102
# 2     Boston Red Stockings       South End Grounds I         NaN  103   98
# 3      Washington Olympics          Olympics Grounds         NaN   94   98
# 4         New York Mutuals  Union Grounds (Brooklyn)         NaN   90   88
#
#    teamIDBR  teamIDlahman45  teamIDretro
# ...

# %% [markdown]
# #### Problem 1(b)
#
# Summarize the Salaries DataFrame to show the total salaries for each team for each year. Show the head of the new summarized DataFrame.

# %%
#dfS.head()
dfSyear = dfS.groupby(by=['yearID', 'teamID'], as_index=False).sum()
#dfSyear = dfSyear.reset_index()
dfSyear.head(40)
# Out:
#     yearID teamID    salary
# 0     1985    ATL  14807000
# 1     1985    BAL  11560712
# 2     1985    BOS  10897560
# 3     1985    CAL  14427894
# 4     1985    CHA   9846178
# 5     1985    CHN  12702917
# 6     1985    CIN   8359917
# 7     1985    CLE   6551666
# 8     1985    DET  10348143
# 9     1985    HOU   9993051
# 10    1985    KCA   9321179
# 11    1985    LAN  10967917
# 12    1985    MIN   5764821
# 13    1985    ML4  11284107
# 14    1985    MON   9470166
# 15    1985    NYA  14238204
# 16    1985    NYN  10834762
# 17    1985    OAK   9058606
# 18    1985    PHI  10124966
# 19    1985    PIT   9227500
# 20    1985    SDN  11036583
# 21    1985    SEA   4613000
# 22    1985    SFN   8221714
# 23    1985    SLN  11817083
# 24    1985    TEX   7676500
# 25    1985    TOR   8812550
# 26    1986    ATL  17102786
# 27    1986    BAL  13001258
# 28    1986    BOS  14402239
# 29    1986    CAL  14427258
# 30    1986    CHA  10418819
# 31    1986    CHN  17208165
# ...

# %% [markdown]
# #### Problem 1(c)
#
# Merge the new summarized Salaries DataFrame and Teams DataFrame together to create a new DataFrame
# showing wins and total salaries for each team for each year year. Show the head of the new merged DataFrame.
#
# **Hint**: Merge the DataFrames using `teamID` and `yearID`.

# %%
# select distinct yearID, teamID, Wins from Teams
dfTL = dfT.loc[:, ['yearID', 'teamID', 'W']]
#dftemp = dftemp.drop_duplicates('yearID')

# select yearID, teamID, salary from Teams T, Salaries S where T.yearID = S.yearID and T.teamID = S.teamID
dfTS = pd.merge(dfTL, dfSyear, on=['yearID', 'teamID'], how='inner')
'''
# Another way of doing inner join
dfTL = dftemp.set_index(keys='yearID', append=True) 
dfTS = dfTL.join(dfSyear)
dfTS = dfTS.reset_index()
dfTS.drop('level_0', axis=1, inplace=True)
'''
dfTS[dfTS.teamID.isin(['OAK'])]
# Out:
#      yearID teamID    W    salary
# 11     1985    OAK   77   9058606
# 36     1986    OAK   76   9779421
# 61     1987    OAK   81  11680839
# 85     1988    OAK  104   9690000
# 111    1989    OAK   99  15613070
# 137    1990    OAK  103  19887501
# 166    1991    OAK   84  36999167
# 189    1992    OAK   96  41035000
# 221    1993    OAK   68  37812333
# 247    1994    OAK   51  34172500
# 277    1995    OAK   67  37739225
# 304    1996    OAK   78  21243000
# 333    1997    OAK   65  24018500
# 361    1998    OAK   74  21303000
# 389    1999    OAK   87  24431833
# 418    2000    OAK   91  31971333
# 449    2001    OAK  102  33810750
# 478    2002    OAK  103  40004167
# 508    2003    OAK   96  50260834
# 539    2004    OAK   91  59425667
# 569    2005    OAK   88  55425762
# 598    2006    OAK   93  62243079
# 630    2007    OAK   76  79366940
# 660    2008    OAK   75  47967126
# 691    2009    OAK   75  61910000
# 719    2010    OAK   81  55254900
# ...

# %%
dfTS.tail(20)
# Out:
#      yearID teamID   W     salary
# 808    2013    OAK  96   60132500
# 809    2013    TEX  91  112522600
# 810    2013    LAA  78  124174750
# 811    2013    SEA  71   74005043
# 812    2013    HOU  51   17890700
# 813    2013    SLN  97   92260110
# 814    2013    PIT  94   77062000
# 815    2013    CIN  90  106404462
# 816    2013    MIL  74   76947033
# 817    2013    CHN  66  100567726
# 818    2013    ATL  96   87871525
# 819    2013    WAS  86  113703270
# 820    2013    NYN  74   49448346
# 821    2013    PHI  73  169863189
# 822    2013    MIA  62   33601900
# 823    2013    LAN  92  223362196
# 824    2013    ARI  81   90132000
# 825    2013    SDN  76   65585500
# 826    2013    SFN  76  140180334
# 827    2013    COL  74   74409071

# %% [markdown]
# #### Problem 1(d)
#
# How would you graphically display the relationship between total wins and total salaries for a given year? What kind of plot would be best? Choose a plot to show this relationship and specifically annotate the Oakland baseball team on the on the plot. Show this plot across multiple years. In which years can you detect a competitive advantage from the Oakland baseball team of using data science? When did this end?
#
# **Hints**: Use a `for` loop to consider multiple years. Use the `teamID` (three letter representation of the team name) to save space on the plot.

# %%
teamName = 'OAK'
years = np.arange(2000,2005)
for yr in years: 
    df = dfTS[dfTS.yearID == yr]
    plt.scatter(df.salary/1e6, df.W, c='red')
    plt.title('Wins versus Salaries in year ' + str(yr))
    plt.xlabel('Total Salary (in millions)')
    plt.ylabel('Wins')
    plt.xlim(0, 180)
    plt.ylim(30, 130)
    plt.grid()
    
    plt.annotate(teamName, xy=(df.salary[df.teamID == teamName]/1e6, df.W[df.teamID == teamName]), 
                 xytext = (-20, 20), textcoords = 'offset points', ha = 'right', va = 'bottom',
                 arrowprops = dict(arrowstyle = '->', facecolor = 'black' , connectionstyle = 'arc3,rad=0'))

    plt.show()

#cha = dfTS[dfTS.teamID.isin(['CHA'])]
#plt.scatter(cha.salary, cha.W)

# %% [markdown]
# #### Problem 1(e):
#
# **For AC209 Students**: Fit a linear regression to the data from each year and obtain the residuals. Plot the residuals against time to detect patterns that support your answer in 1(d).

# %%
from scipy import stats

df = dfTS[dfTS.yearID == 2000]
slope, intercept, r_value, p_value, std_err = stats.linregress(df.salary, df.W)
plt.plot(df.salary, slope*df.salary+intercept, '--', color='blue')
plt.scatter(df.salary, df.W, c='red')
plt.show()


years = np.arange(2000, 2004)
residuals = pd.DataFrame()

for yr in years:
    df = dfTS[dfTS.yearID == yr]
    x_list = df.salary.values/1e6
    y_list = df.W.values
    slope, intercept, r_value, p_value, std_err = stats.linregress(x_list, y_list)
    residuals[yr] = y_list - (slope*x_list+intercept)
    
    
residuals.index = df.teamID
residuals = residuals.T
print residuals.head()
residuals.index = residuals.index.format() #render a string representation of the index
residuals.plot(figsize = (15, 8),
               color=map(lambda x: 'blue' if x=='OAK' else 'gray',df.teamID))


    
    #plt.plot(oak.yearID, residuals, 'ro')
    #plt.grid(True)
    #markerline, stemlines, baseline = plt.stem(df.yearID, residuals, '-.')
    #plt.setp(markerline, 'markerfacecolor', 'b')
    #plt.setp(baseline, 'color','r', 'linewidth', 2)
    #plt.axis([1985,2015,-40,40])
# Out:
# teamID        MIN        CHA       KCA        CLE        DET       NYA  \
# 2000    17.834225   5.926110 -2.354381   1.023034  -5.909655  0.385391
# 2001     5.374796  11.025243  2.016329 -12.918064 -10.880855  6.144913
# 2002    20.315512   2.920130 -9.857422 -13.490451 -22.549915  6.713596
# 2003    12.117475   9.015522  8.111698  -8.499958 -33.616468  3.689126
#
# teamID       BOS       TOR        BAL        TBA    ...            ATL  \
# 2000    0.608153  3.718464 -10.933275 -13.049088    ...       9.589626
# 2001   -6.475081 -2.881301 -18.312122 -17.519615    ...       2.580021
# 2002    1.356053 -5.316818 -11.989368 -17.086560    ...      13.452166
# 2003    8.238596  8.963777 -10.553130  -7.715129    ...      12.980497
#
# teamID        FLO       PHI        MON        NYN        SFN        LAN  \
# 2000     9.365862  3.572784 -10.453051 -14.662805  16.344554   0.066824
# 2001     9.065650 -3.628990   0.061755  -7.836462   7.736789   9.416959
# ...

# %% [markdown]
# ## Discussion for Problem 1
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---

# %% [markdown]
# ## Problem 2
#
# Several media reports have demonstrated the income inequality has increased in the US during this last decade. Here we will look at global data. Use exploratory data analysis to determine if the gap between Africa/Latin America/Asia and Europe/NorthAmerica has increased, decreased or stayed the same during the last two decades.

# %% [markdown]
# #### Problem 2(a)
#
# Using the list of countries by continent from [World Atlas](http://www.worldatlas.com/cntycont.htm) data, load in the `countries.csv` file into a pandas DataFrame and name this data set as `countries`.  This data set can be found on Github in the 2014_data repository [here](https://github.com/cs109/2014_data/blob/master/countries.csv).

# %%
import requests
import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
r = requests.get(url).content
s = StringIO.StringIO(r)
countries = pd.read_csv(url)
countries.head()
# Out:
#     Country  Region
# 0   Algeria  AFRICA
# 1    Angola  AFRICA
# 2     Benin  AFRICA
# 3  Botswana  AFRICA
# 4   Burkina  AFRICA

# %% [markdown]
# Using the [data available on Gapminder](http://www.gapminder.org/data/), load in the [Income per person (GDP/capita, PPP$ inflation-adjusted)](https://spreadsheets.google.com/pub?key=phAwcNAVuyj1jiMAkmq1iMg&gid=0) as a pandas DataFrame and name this data set as `income`.
#
# **Hint**: Consider using the pandas function `pandas.read_excel()` to read in the .xlsx file directly.

# %%
url0 = "https://spreadsheets.google.com/pub?key=phAwcNAVuyj1jiMAkmq1iMg&output=xls"
income = pd.read_excel(StringIO.StringIO(requests.get(url0).content), sheetname="Data")
income.head()
# Out:
#              gdp pc test        1800        1801        1802        1803  \
# 0               Abkhazia         NaN         NaN         NaN         NaN
# 1            Afghanistan  472.053500  472.053500  472.053500  472.053500
# 2  Akrotiri and Dhekelia         NaN         NaN         NaN         NaN
# 3                Albania  601.215222  601.839631  602.464688  603.090394
# 4                Algeria  766.253664  766.234779  766.215895  766.197011
#
#          1804        1805        1806        1807        1808     ...      \
# 0         NaN         NaN         NaN         NaN         NaN     ...
# 1  472.053500  472.053500  472.053500  472.053500  472.053500     ...
# 2         NaN         NaN         NaN         NaN         NaN     ...
# 3  603.716751  604.343757  604.971415  605.599725  606.228687     ...
# 4  766.178127  766.159244  766.140362  766.121480  766.102598     ...
#
#           2003         2004  2005         2006         2007         2008  \
# ...

# %% [markdown]
# Transform the data set to have years as the rows and countries as the columns. Show the head of this data set when it is loaded.

# %%
income.index = income[income.columns[0]].values
income = income.drop(income.columns[0], axis=1)
income = income.T

income.head()
# Out:
#       Abkhazia  Afghanistan  Akrotiri and Dhekelia     Albania     Algeria  \
# 1800       NaN     472.0535                    NaN  601.215222  766.253664
# 1801       NaN     472.0535                    NaN  601.839631  766.234779
# 1802       NaN     472.0535                    NaN  602.464688  766.215895
# 1803       NaN     472.0535                    NaN  603.090394  766.197011
# 1804       NaN     472.0535                    NaN  603.716751  766.178127
#
#       American Samoa      Andorra      Angola    Anguilla  \
# 1800      674.453726  1260.123256  359.932582  775.668711
# 1801      674.453726  1262.214402  359.932582  775.668711
# 1802      674.453726  1264.309018  359.932582  775.668711
# 1803      674.453726  1266.407109  359.932582  775.668711
# 1804      674.453726  1268.508683  359.932582  775.668711
#
#       Antigua and Barbuda         ...           Western Sahara     Vietnam  \
# 1800           538.376199         ...                      NaN  459.708986
# ...

# %% [markdown]
# #### Problem 2(b)
#
# Graphically display the distribution of income per person across all countries in the world for any given year (e.g. 2000).  What kind of plot would be best?

# %%
year = 2000
incomex = income.loc[year].dropna().values
print incomex

plt.hist(incomex, bins=30)
plt.ylabel('Frequency')
plt.xlabel('Income per person')
plt.title('Income per person by country, year %i' % year)
plt.show()

incomexlog = np.log(incomex)
plt.hist(incomexlog, bins=30)
plt.ylabel('Frequency')
plt.xlabel('Logarithm of income per person')
plt.title('Log(income per person) by country, year %i' % year)
plt.show()
# Out:
# [   663.90987773   4195.21036764   5098.85356434   7650.44911293
#   30265.94105353   2446.64587312  15551.72564198  12738.74463055
#   10571.36362417   2114.05687416  28711.44200381  29241.51449823
#   32008.50465994   2533.1701537   22728.40825593  22015.32286197
#    1075.43458285  14982.1229375    5936.23781934  29940.20469901
#    6545.45313936   1307.56823179  60167.71419182   2922.1141781
#    3394.70806665   5733.14817973  10107.98688509   8056.06091514
#   42980.91474985  48020.35456624   6907.01372155   1001.4772692
#     443.76473958    982.35577206   1803.43680283  32448.6076372
#    2291.28956248  49156.95627426    762.18076882   1017.0349964
#   10435.17428573   3407.51411436   5749.55201207   1090.79469906
#     292.45104781   3423.52226456  13288.47187561   7672.84695073
#    1746.31265813  10582.66816726   6115.59394208  22821.38149567
#   16823.23775083  31805.53531006   1894.03763082   8189.15768071
#    4350.08012126   5616.4188037    4629.45900313   5341.2732338
# ...

# %% [markdown]
# #### Problem 2(c)
#
# Write a function to merge the `countries` and `income` data sets for any given year.

# %%
"""
Function
--------
mergeByYear

Return a merged DataFrame containing the income, 
country name and region for a given year. 

Parameters
----------
year : int
    The year of interest

Returns
-------
a DataFrame
   A pandas DataFrame with three columns titled 
   'Country', 'Region', and 'Income'. 

Example
-------
>>> mergeByYear(2010)
"""
def mergeByYear(year):
    incomeyr = pd.DataFrame(income.loc[year, :].dropna())
    #print incomeyr.head()
    incomeyr.columns=['Income']
    incomeyr['Country'] = incomeyr.index.values
    joined = pd.merge(incomeyr, countries, on='Country')
    joined.Income = np.round(joined.Income, 2)
    return joined
dat = mergeByYear(2000)
dat_asia = dat[dat.Region == 'ASIA']
dat_asia.sort(columns='Income', ascending=False)
#dat = dat.groupby(by=['Region'], as_index=False).mean()
#dat.head()
# Out:
#        Income               Country Region
# 127  60394.43                 Qatar   ASIA
# 24   48020.35                Brunei   ASIA
# 141  36834.85             Singapore   ASIA
# 81   36397.96                Kuwait   ASIA
# 167  30012.32  United Arab Emirates   ASIA
# 76   28559.60                 Japan   ASIA
# 73   22834.93                Israel   ASIA
# 12   22015.32               Bahrain   ASIA
# 136  20001.87          Saudi Arabia   ASIA
# 117  19204.29                  Oman   ASIA
# 94   10161.49              Malaysia   ASIA
# 70    8600.73                  Iran   ASIA
# 162   6803.29                Turkey   ASIA
# 85    5795.29               Lebanon   ASIA
# 157   5578.40              Thailand   ASIA
# 78    5366.02            Kazakhstan   ASIA
# 71    3951.74                  Iraq   ASIA
# 154   3935.37                 Syria   ASIA
# 77    3664.56                Jordan   ASIA
# 95    3433.50              Maldives   ASIA
# 33    3407.51                 China   ASIA
# ...

# %% [markdown]
# #### Problem 2(d)
#
# Use exploratory data analysis tools such as histograms and boxplots to explore the distribution of the income per person by region data set from 2(c) for a given year. Describe how these change through the recent years?
#
# **Hint**: Use a `for` loop to consider multiple years.

# %%
from matplotlib import dates
years = np.arange(2000, 2005)

for yr in years:
    data = mergeByYear(yr)
    data.boxplot('Income', by = 'Region', rot=90)
    plt.title('Incomer per capita by region, %i' % yr)
    plt.ylabel('Income per person (log10 scale)')
    plt.yscale('log')
 
dat05 = mergeByYear(2005)
dat05.groupby('Region').hist(bins=40)
plt.ylim(0,20)

trends = pd.DataFrame()
for yr in years:
    data = mergeByYear(yr)
    data = data.groupby(by='Region', as_index=False).mean()
    data['Year'] = [yr] * len(data)
    trends = pd.concat([trends, data])


trends.index = range(1, len(trends)+1)
trends
# Out:
#            Region        Income  Year
# 1          AFRICA   2742.220612  2000
# 2            ASIA  10954.899474  2000
# 3          EUROPE  21772.960465  2000
# 4   NORTH AMERICA  10899.161818  2000
# 5         OCEANIA   7993.074615  2000
# 6   SOUTH AMERICA   6738.928333  2000
# 7          AFRICA   2830.778367  2001
# 8            ASIA  10903.326842  2001
# 9          EUROPE  22220.930698  2001
# 10  NORTH AMERICA  10842.019545  2001
# 11        OCEANIA   8142.748462  2001
# 12  SOUTH AMERICA   6727.460000  2001
# 13         AFRICA   2880.500204  2002
# 14           ASIA  11059.330000  2002
# 15         EUROPE  22518.136977  2002
# 16  NORTH AMERICA  10929.099545  2002
# 17        OCEANIA   8227.098462  2002
# 18  SOUTH AMERICA   6498.546667  2002
# 19         AFRICA   2952.861837  2003
# 20           ASIA  11397.733158  2003
# 21         EUROPE  22860.386977  2003
# 22  NORTH AMERICA  11169.180000  2003
# 23        OCEANIA   8363.868462  2003
# 24  SOUTH AMERICA   6592.860833  2003
# ...

# %% [markdown]
# ## Discussion for Problem 2
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---

# %% [markdown]
# ## Problem 3
#
# In general, if group A has larger values than group B on average, does this mean the largest values are from group A? Discuss after completing each of the problems below.

# %% [markdown]
# #### Problem 3(a)
#
# Assume you have two list of numbers, X and Y, with distribution approximately normal. X and Y have standard deviation equal to 1, but the average of X is different from the average of Y.  If the difference in the average of X and the average of Y is larger than 0, how does the proportion of X > a compare to the proportion of Y > a?

# %% [markdown]
# Write a function that analytically calculates the ratio of these two proportions: Pr(X > a)/Pr(Y > a) as function of the difference in the average of X and the average of Y.
#
# **Hint**: Use the `scipy.stats` module for useful functions related to a normal random variable such as the probability density function, cumulative distribution function and survival function.
#
# **Update**: Assume Y is normally distributed with mean equal to 0.

# %% [markdown]
# Show the curve for different values of a (a = 2,3,4 and 5).

# %%
"""
Function
--------
ratioNormals

Return ratio of these two proportions: 
    Pr(X > a)/Pr(Y > a) as function of 
    the difference in the average of X 
    and the average of Y. 

Parameters
----------
diff : difference in the average of X 
    and the average of Y. 
a : cutoff value

Returns
-------
Returns ratio of these two proportions: 
    Pr(X > a)/Pr(Y > a)
    
Example
-------
>>> ratioNormals(diff = 1, a = 2)
"""
#your code here
import scipy.stats as stats
def ratioNormals(diff=1, a):
    y = stats.norm(loc=0, scale=1)
    x = stats.norm(loc=diff, scale=1)
    #return (1-x.cdf(a))/(1-y.cdf(a))
    return x.sf(a)/y.sf(a)
ratioNormals(diff = 1, a = 2)
# Out:
# 6.9738168680887602

# %%
#your code here
As = range(2,6)
diffs = np.linspace(0, 5, 50)

for a in As:
    Rs = [ratioNormals(d, a) for d in diffs]
    plt.plot(diffs, Rs)
    
plt.legend(["a=%s"%a for a in As], loc=0)
plt.yscale('log')

# %% [markdown]
# #### Problem 3(b)
#
# Now consider the distribution of income per person from two regions: Asia and South America. Estimate the average income per person across the countries in those two regions. Which region has the larger average of income per person across the countries in that region?
#
# **Update**: Use the year 2012.

# %%
#your code here
year = 2012
df = mergeByYear(2012)
merged = df.groupby('Region', as_index=False).mean()
merged = merged[(merged.Region == 'ASIA')|(merged.Region == 'SOUTH AMERICA')]


dfAS = df[(df.Region == 'ASIA') | (df.Region == 'SOUTH AMERICA')]
dfAS.boxplot('Income', by='Region')
plt.yscale('log')


byRegion = df.groupby('Region')


def ratio_of_region(grouped_data, a):
    ratios = [len(group[group.Income>a])*1.0/len(group) for key, group in grouped_data]
    Z = pd.DataFrame(grouped_data.mean())
    Z['Region'] = Z.index
    Z['Ratio above %s' % a] = ratios
    Z.index = range(1, len(Z)+1)
    return Z

a = 10000
rr = ratio_of_region(byRegion, a)
asia_south_america = rr[(rr.Region == 'ASIA') | (rr.Region == 'SOUTH AMERICA')]

asia_south_america
# Out:
#          Income         Region  Ratio above 10000
# 2  14510.041842           ASIA           0.368421
# 6   9471.470000  SOUTH AMERICA           0.416667

# %% [markdown]
# #### Problem 3(c)
#
# Calculate the proportion of countries with income per person that is greater than 10,000 dollars. Which region has a larger proportion of countries with income per person greater than 10,000 dollars? If the answer here is different from the answer in 3(b), explain why in light of your answer to 3(a).
#
# **Update**: Use the year 2012.

# %%
ratioSA = len(SA[SA.Income > 10000])*1.0/len(SA)
ratioAsia = len(Asia[Asia.Income > 10000])*1.0/len(Asia)
print ratioSA, ratioAsia
# Out:
# 0.416666666667 0.368421052632

# %% [markdown]
# #### Problem 3(d)
#
# **For AC209 Students**: Re-run this analysis in Problem 3 but compute the average income per person for each region, instead of the average of the reported incomes per person across countries in the region. Why are these two different? Hint: use this [data set](https://spreadsheets.google.com/pub?key=phAwcNAVuyj0XOoBL_n5tAQ&gid=0).

# %%
#your code here
s = StringIO.StringIO(requests.get("https://spreadsheets.google.com/pub?key=phAwcNAVuyj0XOoBL_n5tAQ&output=xls").content)
popdat = pd.read_excel(s, sheetname="Data")

popdat.columns = ['Country'] + list(popdat.columns)[1:]
popdat.head()
# Out:
#                  Country     1700  1730  1750  1785  1786  1787  1788  1789  \
# 0               Abkhazia      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1            Afghanistan      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  Akrotiri and Dhekelia      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3                Albania   300000   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4                Algeria  1750000   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    1790  ...       2004      2005      2006      2007      2008      2009  \
# 0   NaN  ...        NaN       NaN       NaN       NaN       NaN       NaN
# 1   NaN  ...   26693486  27614718  28420974  29145841  29839994  30577756
# 2   NaN  ...        NaN     15700       NaN       NaN     15700       NaN
# 3   NaN  ...    3124861   3141800   3156607   3169665   3181397   3192723
# 4   NaN  ...   32396048  32888449  33391954  33906605  34428028  34950168
#
#        2010      2011      2012      2013
# ...

# %%
#df.head()
#df is income by country by region data in 2012

pop = popdat.loc[:, ['Country', 2012]].dropna()
pop.columns = ['Country', 'Population']
pop = pd.merge(pop, df, on='Country')
pop['Total Income'] = pop['Population']*pop['Income']

popByRegion = pop.groupby('Region', as_index=False).sum()
popByRegion['Average Income Over Population'] = popByRegion['Total Income']/popByRegion['Population']

popByRegion
# Out:
#           Region  Population     Income  Total Income  \
# 0         AFRICA   951982255  179990.89  2.858548e+12
# 1           ASIA  4048448110  551381.59  2.725280e+13
# 2         EUROPE   596814948  887036.84  1.475802e+13
# 3  NORTH AMERICA   537471777  275961.28  1.645682e+13
# 4        OCEANIA    36692074   93308.15  9.641701e+11
# 5  SOUTH AMERICA   400557572  113657.64  4.226231e+12
#
#    Average Income Over Population
# 0                     3002.732732
# 1                     6731.664718
# 2                    24727.970720
# 3                    30618.945171
# 4                    26277.340326
# 5                    10550.870469

# %% [markdown]
# ## Discussion for Problem 3
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---
